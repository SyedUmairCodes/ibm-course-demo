# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Syed Umair Ali**
# Full stack developer

# %% [markdown]
# *I am interested in data science because I love to explore data and I find that data is just an amazing thing and if utilized correctly we can do a lot of great things with it*

# %% [markdown]
# ### A simple code snippet for printing the result of 2+2

# %%
print(2+2)

# %% [markdown]
# ```
# This is how code blocks are written in Markdown
# ```
# - This is a bulleted list
# - This is another bulleted list
#
# 1. This is a numbered list
# 2. This is another numbered list
